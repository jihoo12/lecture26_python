# %%
t1 = (1,2,3)
t2=('a','b',('ab','cd'))
t3 = ('tuple',(1,2),[3,4])

# %%
t4= ()
t5=(1,)
t6=1,2,3
t7 = 1,
print(t6)
x,y,z = t6
print(x,y,z)

# %%
for i in t1:
    print(i)
# Out:
# 1
# 2
# 3

# %%
x,y=10,20
x,y=y,x
