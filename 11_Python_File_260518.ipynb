# %%
filename = 'sample.txt'

file = open(filename,"w")
for i in range(5):
    file.write("hello\n")
file.close

with open(filename,encoding="utf-8") as f_read:
    content = f_read.read()
print(content)
# Out:
# hello
# hello
# hello
# hello
# hello
