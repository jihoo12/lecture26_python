# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from math import pi
print(pi)
# Out:
# 3.141592653589793

# %%
from math import pi as p
print(p)
# Out:
# 3.141592653589793
